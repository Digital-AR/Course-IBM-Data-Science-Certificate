# %% [markdown]
# **IMPORT BEAUTIFULSOUP & OTHER NEEDED LIBRARIES**

# %%
# !pip install lxml
# !pip install bs4
# !pip install Geopy
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# **LOAD SOURCE WEBPAGE AND ASSIGN VARIABLE SOURCE**

# %%
Data = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
Soup = BeautifulSoup(Data, 'html.parser')

# %% [markdown]
# **LOAD CSV WRITER AND ADD COLUMNS NAMES ON THE 1ST ROW**

# %%
csv_file = open('toronto_postal_codes.csv', 'w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['PostalCode', 'Borough', 'Neighborhood'])
# Out:
# 33

# %% [markdown]
# **PART 1: SCRAPE THE WEBPAGE**

# %%
table = Soup.find('table', class_ = 'wikitable sortable') 
rows = table.find_all('tr') 

PostalCodes = [] 
Boroughs = [] 
Neighborhoods = [] 

for row in Soup.find('table').find_all('tr'):
    cells = row.find_all('td')
    if(len(cells) > 0):
        PostalCodes.append(cells[0].text)
        Boroughs.append(cells[1].text)
        Neighborhoods.append(cells[2].text.rstrip('\n'))

if Neighborhoods == 'Not assigned': 
    Neighborhoods = Borough            
                
Neighborhoods.append(cells[2].text.rstrip('\n'))

# %% [markdown]
# **PLACE THE SCRAPED DATA INTO A DATAFRAME**

# %%
Toronto_Neighborhood = {'PostalCode' : PostalCodes ,'Borough' : Boroughs , 'Neighborhood': Neighborhoods}
Toronto_DF = pd.DataFrame.from_dict(Toronto_Neighborhood, orient='index')
Toronto_DF.transpose()
# Out:
#     PostalCode             Borough  \
# 0        M1A\n      Not assigned\n
# 1        M2A\n      Not assigned\n
# 2        M3A\n        North York\n
# 3        M4A\n        North York\n
# 4        M5A\n  Downtown Toronto\n
# 5        M6A\n        North York\n
# 6        M7A\n  Downtown Toronto\n
# 7        M8A\n      Not assigned\n
# 8        M9A\n         Etobicoke\n
# 9        M1B\n       Scarborough\n
# 10       M2B\n      Not assigned\n
# 11       M3B\n        North York\n
# 12       M4B\n         East York\n
# 13       M5B\n  Downtown Toronto\n
# 14       M6B\n        North York\n
# 15       M7B\n      Not assigned\n
# 16       M8B\n      Not assigned\n
# 17       M9B\n         Etobicoke\n
# 18       M1C\n       Scarborough\n
# 19       M2C\n      Not assigned\n
# 20       M3C\n        North York\n
# 21       M4C\n         East York\n
# 22       M5C\n  Downtown Toronto\n
# 23       M6C\n              York\n
# 24       M7C\n      Not assigned\n
# ...

# %% [markdown]
# **REMOVE 'NOT ASSIGNED' ROWS**

# %%
! pip install lxml
import pandas as pd
Webpage = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
Toronto_DF = Webpage[0]
Toronto_DF['Borough'].replace("Not assigned", inplace = True)

Toronto_DF_dropna = Toronto_DF[Toronto_DF.Borough != 'Not assigned'].reset_index(drop=True)
Toronto_DF_dropna.head(12)
# Out:
# ...
#    Postal Code           Borough                                Neighbourhood
# 0          M3A        North York                                    Parkwoods
# 1          M4A        North York                             Victoria Village
# 2          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3          M6A        North York             Lawrence Manor, Lawrence Heights
# 4          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5          M8A  Downtown Toronto                                 Not assigned
# 6          M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 7          M1B       Scarborough                               Malvern, Rouge
# 8          M2B       Scarborough                                 Not assigned
# 9          M3B        North York                                    Don Mills
# 10         M4B         East York              Parkview Hill, Woodbine Gardens
# ...

# %%
Toronto_DF.shape
# Out:
# (180, 3)

# %% [markdown]
# **COMBINE NEIGHBORHOODS BY POSTAL CODE AND BOROUGH**

# %%
PCN_DF = Toronto_DF.groupby(['Postal Code', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
PCN_DF.columns = ['Postal Code', 'Borough', 'Neighbourhood']
PCN_DF.head(12)
# Out:
#    Postal Code       Borough  \
# 0          M1A  Not assigned
# 1          M1B   Scarborough
# 2          M1C   Scarborough
# 3          M1E   Scarborough
# 4          M1G   Scarborough
# 5          M1H   Scarborough
# 6          M1J   Scarborough
# 7          M1K   Scarborough
# 8          M1L   Scarborough
# 9          M1M   Scarborough
# 10         M1N   Scarborough
# 11         M1P   Scarborough
#
#                                         Neighbourhood
# 0                                        Not assigned
# 1                                      Malvern, Rouge
# 2              Rouge Hill, Port Union, Highland Creek
# 3                   Guildwood, Morningside, West Hill
# 4                                              Woburn
# 5                                           Cedarbrae
# 6                                 Scarborough Village
# 7         Kennedy Park, Ionview, East Birchmount Park
# 8                     Golden Mile, Clairlea, Oakridge
# ...

# %% [markdown]
# **FOR NEIGHBOODS 'NOT ASSIGNED', ASSIGN SAME VALUE AS BOROUGH**

# %%
Toronto_DF['Neighbourhood'].replace('Not assigned', "Queen's Park", inplace=True)
Toronto_DF.head(12)
# Out:
#    Postal Code           Borough                                Neighbourhood
# 0          M1A      Not assigned                                 Queen's Park
# 1          M2A      Not assigned                                 Queen's Park
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7          M8A  Downtown Toronto                                 Queen's Park
# 8          M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9          M1B       Scarborough                               Malvern, Rouge
# 10         M2B       Scarborough                                 Queen's Park
# ...

# %% [markdown]
# **LOAD THE COORDINATES FROM THE CSV FILE**

# %%
import pandas as pd
Coordinates = pd.read_csv("Geospatial_Coordinates.csv")
Coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# **RENAME 'Postal Code' COLUMN TO "PostalCode"**

# %%
Coordinates.rename(columns={"Postal Code": "PostalCode"}, inplace=True)
Coordinates.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %% [markdown]
# **MERGE THE TABLE TO SHOW THE COORDINATES**

# %%
Toronto_DF_new = Toronto_DF_Grouped.groupby(Coordinates, on= {'Postal Code'}, how="left")
Toronto_DF_new.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-7ca841e9167e> in <module>
# ----> 1 Toronto_DF_new = Toronto_DF_Grouped.groupby(Coordinates, on= {'Postal Code'}, how="left")
#       2 Toronto_DF_new.head()
#       3
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
Toronto_DF_new = Toronto_DF_Grouped.merge(Coordinates, on= "PostalCode", how="left")
Toronto_DF_new.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-ab6d882e9d89> in <module>
# ----> 1 Toronto_DF_new = Toronto_DF_Grouped.merge(Coordinates, on= "PostalCode", how="left")
#       2 Toronto_DF_new.head()
#
# AttributeError: 'list' object has no attribute 'merge'
